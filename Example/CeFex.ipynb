# %%
### ScaleR example ### 

library(ScaleR)

# %%
x <- read.csv('RE _Re_ScaleR/CFEX_CE.csv')

# %%
y <- read.csv('RE _Re_ScaleR/CFEX_Type.csv')

# %%
head(x)
# Out:
#   X1.2981e.05 X3.6452e.05 X3.6066e.05 X3.5779e.05 X3.5535e.05 X3.5404e.05
# 1 1.1862e-06   17700       11508       17267       28459       35302
# 2 2.6808e-06   76205       76236       76190       76088       75909
# 3 7.9777e-06  225030      222850      219610      216230      212820
# 4 4.4223e-06  125380      124860      123990      122740      121170
# 5 5.8179e-06  163930      162620      161070      159480      157860
# 6 6.5361e-06  183640      181880      180200      178800      177390
#   X3.537e.05 X3.5447e.05 X3.5643e.05 X3.5884e.05 ⋯ X.32089 X.31768   X.32921
# 1  32370      22920       11297        4018.7    ⋯   21437   14975.0   10562.0
# 2  75662      75322       74919       74448.0    ⋯  -81549  -89216.0  -95722.0
# 3 209490     206300      203250      201580.0    ⋯  -38175  -37292.0  -33820.0
# 4 120190     119850      120410      121670.0    ⋯   -9149   -5513.7   -5575.9
# 5 156030     154000      151630      149260.0    ⋯  -31280  -35313.0  -37550.0
# ...

# %%
head(y)
# Out:
#   X1
# 1 1
# 2 1
# 3 0
# 4 0
# 5 0
# 6 0

# %%
CFeX.Res_0.5<- ScaleR(x ,y$X1,method='PLS', inter=0.5, seed_val=1234, plot=TRUE, k=1)
# Out:
#  num 1234
# [1] "Employing PLS"
#  int 1
# Plot with title “Scaling Factor vs R2 and Q2”

# %%
CFeX.Res_0.1<- ScaleR(x ,y$X1,method='PLS', inter=0.1, seed_val=1234, plot=TRUE, k=1)
# Out:
#  num 1234
# [1] "Employing PLS"
#  int 1
# Plot with title “Scaling Factor vs R2 and Q2”

# %%
CFeX.Res_0.01<- ScaleR(x ,y$X1,method='PLS', inter=0.01, seed_val=1234, plot=TRUE, k=1)
# Out:
#  num 1234
# [1] "Employing PLS"
#  int 6
# Plot with title “Scaling Factor vs R2 and Q2”
